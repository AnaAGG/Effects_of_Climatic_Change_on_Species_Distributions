# %%
import pygbif
from pygbif import occurrences as occ
from pygbif import species

import requests

import pandas as pd

# %%
response = requests.get('http://api.gbif.org/v1/occurrence/counts/datasets')
response.status_code
# Out:
# 200

# %%
splist = ['Apus affinis', 'Apus caffer', 'Parnasius apollo', 'Calotriton arnoldi', 'Gallotia simonyi', 'Alytes dickhilleni',
'Meliataea cinxia', 'Silene ciliata', 'Abies pinsapo', 'Lanius minor', 'Ciconia ciconia']

def get_species_name_from_codes (sp):
    keys = [species.name_backbone(x)['usageKey'] for x in splist ]
    species_codes = dict(zip(splist, keys))
    return species_codes

# %%
code_number = get_species_name_from_codes(splist)
code_number
# Out:
# {'Apus affinis': 5228662,
#  'Apus caffer': 5228644,
#  'Parnasius apollo': 1938810,
#  'Calotriton arnoldi': 2431827,
#  'Gallotia simonyi': 2468673,
#  'Alytes dickhilleni': 2426613,
#  'Meliataea cinxia': 8168644,
#  'Silene ciliata': 7267056,
#  'Abies pinsapo': 2685464,
#  'Lanius minor': 2492854,
#  'Ciconia ciconia': 2481912}

# %%
response = requests.get('http://api.gbif.org/v1/occurrence/counts/datasets')
response.status_code
# Out:
# 200

# %%
def get_occurences(code_number):
    
    years = range(1970, 2020)
    x = []
    for key,value in code_number.items():
        for y in years:
            data = occ.search(taxonKey = value, limit = 300, country = 'ES', year = str(y))
            #Get the number of occurrences:
            x.append({str(y): data['count']})

            # Set all the data in an unique dictionary
            final = {}
            for d in x:
                for k in d.keys():
                    final[k] = final.get(k,0) + d[k]
       
    return final

# %%
y = get_occurences(code_number)

# %%
y
# Out:
# {'1970': 39,
#  '1971': 22,
#  '1972': 69,
#  '1973': 61,
#  '1974': 88,
#  '1975': 98,
#  '1976': 423,
#  '1977': 241,
#  '1978': 597,
#  '1979': 562,
#  '1980': 1229,
#  '1981': 1282,
#  '1982': 1388,
#  '1983': 1968,
#  '1984': 1429,
#  '1985': 1408,
#  '1986': 1451,
#  '1987': 2101,
#  '1988': 1969,
#  '1989': 1663,
#  '1990': 1549,
#  '1991': 1152,
#  '1992': 1763,
#  '1993': 1486,
#  '1994': 1912,
#  '1995': 1465,
#  '1996': 1768,
#  '1997': 2472,
#  '1998': 2906,
#  '1999': 2708,
#  '2000': 3054,
#  '2001': 3953,
#  '2002': 3225,
#  '2003': 3875,
#  '2004': 3215,
#  '2005': 3386,
#  '2006': 4138,
#  '2007': 5997,
#  '2008': 3530,
#  '2009': 4592,
#  '2010': 4639,
#  '2011': 4798,
#  '2012': 4756,
#  '2013': 9112,
#  '2014': 9941,
#  '2015': 9197,
#  '2016': 11051,
#  '2017': 15296,
#  '2018': 25122,
#  '2019': 29335}

# %%
def get_taxonomic_info(code_number):
    for key, values in code_number.items():
        data = occ.search(taxonKey = values, limit = 300, country = 'ES', year = '2016')
        taxonomic = data["results"] 
    
    
        for dictionary in taxonomic:
            species = dictionary["scientificName"]
            kingdom = dictionary["kingdom"] 
            genus = dictionary['genus']
            family = dictionary['family']           
            country = dictionary["country"]
            records = dictionary['basisOfRecord']
            pub = dictionary['publishingCountry']
            
           
    species_info = {'species': species,
                    'kingdom': kingdom,
                    'Genus': genus, 
                    'Family': family,
                    'country': country,
                    'records': records,
                    'Publishing_country': pub
                   }
    return species_info

# %%
# %%time
y = get_taxonomic_info(code_number)
# Out:
# CPU times: user 328 ms, sys: 62.5 ms, total: 391 ms
# Wall time: 27.1 s

# %%
y
# Out:
# {'species': 'Ciconia ciconia (Linnaeus, 1758)',
#  'kingdom': 'Animalia',
#  'Genus': 'Ciconia',
#  'Family': 'Ciconiidae',
#  'country': 'Spain',
#  'records': 'HUMAN_OBSERVATION',
#  'Publishing_country': 'ES'}

# %%
for key, values in code_number.items():
    data = occ.search(taxonKey = values, limit = 300, country = 'ES', year = '2016')
    taxonomic = data["results"]

# %%
taxonomic
# Out:
# [{'key': 1249281116,
#   'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#   'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#   'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#   'publishingCountry': 'US',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2021-01-30T21:46:57.479+00:00',
#   'lastParsed': '2021-01-30T23:51:25.732+00:00',
#   'crawlId': 250,
#   'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#   'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/rightsHolder': 'Alex',
#      'http://purl.org/dc/terms/identifier': 'https://static.inaturalist.org/photos/2951983/original.jpg?1454261326',
#      'http://purl.org/dc/terms/type': 'StillImage',
#      'http://rs.tdwg.org/dwc/terms/catalogNumber': '2951983',
#      'http://purl.org/dc/terms/publisher': 'iNaturalist',
#      'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'http://purl.org/dc/terms/created': '2016-01-30T14:04:26-08:00',
#      'http://purl.org/dc/terms/format': 'image/jpeg',
#      'http://purl.org/dc/terms/references': 'http://www.inaturalist.org/photos/2951983',
#      'http://purl.org/dc/terms/creator': 'Alex'},
#     {'http://purl.org/dc/terms/rightsHolder': 'Alex',
#      'http://purl.org/dc/terms/identifier': 'https://static.inaturalist.org/photos/2951984/original.jpg?1454261330',
#      'http://purl.org/dc/terms/type': 'StillImage',
#      'http://rs.tdwg.org/dwc/terms/catalogNumber': '2951984',
#      'http://purl.org/dc/terms/publisher': 'iNaturalist',
#      'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'http://purl.org/dc/terms/created': '2016-01-30T11:57:07-08:00',
#      'http://purl.org/dc/terms/format': 'image/jpeg',
#      'http://purl.org/dc/terms/references': 'http://www.inaturalist.org/photos/2951984',
#      'http://purl.org/dc/terms/creator': 'Alex'},
#     {'http://purl.org/dc/terms/rightsHolder': 'Alex',
#      'http://purl.org/dc/terms/identifier': 'https://static.inaturalist.org/photos/2951985/original.jpg?1454261338',
#      'http://purl.org/dc/terms/type': 'StillImage',
#      'http://rs.tdwg.org/dwc/terms/catalogNumber': '2951985',
#      'http://purl.org/dc/terms/publisher': 'iNaturalist',
#      'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'http://purl.org/dc/terms/created': '2016-01-30T13:06:44-08:00',
#      'http://purl.org/dc/terms/format': 'image/jpeg',
#      'http://purl.org/dc/terms/references': 'http://www.inaturalist.org/photos/2951985',
#      'http://purl.org/dc/terms/creator': 'Alex'},
#     {'http://purl.org/dc/terms/rightsHolder': 'Alex',
#      'http://purl.org/dc/terms/identifier': 'https://static.inaturalist.org/photos/2951986/original.jpg?1454261335',
#      'http://purl.org/dc/terms/type': 'StillImage',
#      'http://rs.tdwg.org/dwc/terms/catalogNumber': '2951986',
#      'http://purl.org/dc/terms/publisher': 'iNaturalist',
#      'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'http://purl.org/dc/terms/created': '2016-01-30T13:15:31-08:00',
#      'http://purl.org/dc/terms/format': 'image/jpeg',
#      'http://purl.org/dc/terms/references': 'http://www.inaturalist.org/photos/2951986',
#      'http://purl.org/dc/terms/creator': 'Alex'}]},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'dateIdentified': '2016-01-31T17:28:29',
#   'decimalLongitude': 0.947571,
#   'decimalLatitude': 41.68163,
#   'stateProvince': 'Cataluña',
#   'year': 2016,
#   'month': 1,
#   'day': 30,
#   'eventDate': '2016-01-30T00:00:00',
#   'issues': ['GEODETIC_DATUM_ASSUMED_WGS84',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'modified': '2020-08-07T23:07:12.000+00:00',
#   'lastInterpreted': '2021-01-30T23:51:25.732+00:00',
#   'references': 'https://www.inaturalist.org/observations/2633572',
#   'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#   'identifiers': [],
#   'media': [{'type': 'StillImage',
#     'format': 'image/jpeg',
#     'references': 'http://www.inaturalist.org/photos/2951985',
#     'created': '2016-01-30T21:06:44.000+00:00',
#     'creator': 'Alex',
#     'publisher': 'iNaturalist',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#     'rightsHolder': 'Alex',
#     'identifier': 'https://static.inaturalist.org/photos/2951985/original.jpg?1454261338'},
#    {'type': 'StillImage',
#     'format': 'image/jpeg',
#     'references': 'http://www.inaturalist.org/photos/2951986',
#     'created': '2016-01-30T21:15:31.000+00:00',
#     'creator': 'Alex',
#     'publisher': 'iNaturalist',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#     'rightsHolder': 'Alex',
#     'identifier': 'https://static.inaturalist.org/photos/2951986/original.jpg?1454261335'},
#    {'type': 'StillImage',
#     'format': 'image/jpeg',
#     'references': 'http://www.inaturalist.org/photos/2951983',
#     'created': '2016-01-30T22:04:26.000+00:00',
#     'creator': 'Alex',
#     'publisher': 'iNaturalist',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#     'rightsHolder': 'Alex',
#     'identifier': 'https://static.inaturalist.org/photos/2951983/original.jpg?1454261326'},
#    {'type': 'StillImage',
#     'format': 'image/jpeg',
#     'references': 'http://www.inaturalist.org/photos/2951984',
#     'created': '2016-01-30T19:57:07.000+00:00',
#     'creator': 'Alex',
#     'publisher': 'iNaturalist',
#     'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#     'rightsHolder': 'Alex',
#     'identifier': 'https://static.inaturalist.org/photos/2951984/original.jpg?1454261330'}],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.6_1', 'name': 'Cataluña'},
#    'level2': {'gid': 'ESP.6.3_1', 'name': 'Lleida'},
#    'level3': {'gid': 'ESP.6.3.8_1', 'name': 'n.a. (166)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'rightsHolder': 'Alex',
#   'identifier': '2633572',
#   'http://unknown.org/nick': 'alsamci',
#   'verbatimEventDate': '2016-01-30',
#   'datasetName': 'iNaturalist research-grade observations',
#   'gbifID': '1249281116',
#   'verbatimLocality': "Estany D'Ivars",
#   'collectionCode': 'Observations',
#   'occurrenceID': 'http://www.inaturalist.org/observations/2633572',
#   'taxonID': '4733',
#   'catalogNumber': '2633572',
#   'recordedBy': 'Alex',
#   'http://unknown.org/occurrenceDetails': 'http://www.inaturalist.org/observations/2633572',
#   'institutionCode': 'iNaturalist',
#   'rights': '© Alex some rights reserved',
#   'identifiedBy': 'Alex',
#   'identificationID': '4939442'},
#  {'key': 1338394937,
#   'datasetKey': '6ac3f774-d9fb-4796-b3e9-92bf6c81c084',
#   'publishingOrgKey': 'bb646dff-a905-4403-a49b-6d378c2cf0d9',
#   'installationKey': '36cae45c-1983-48be-9cf9-0672c4a60612',
#   'publishingCountry': 'DE',
#   'protocol': 'BIOCASE',
#   'lastCrawled': '2020-12-10T07:31:48.176+00:00',
#   'lastParsed': '2020-12-15T22:33:57.454+00:00',
#   'crawlId': 138,
#   'hostingOrganizationKey': 'bb646dff-a905-4403-a49b-6d378c2cf0d9',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -6.351814,
#   'decimalLatitude': 38.913208,
#   'coordinateUncertaintyInMeters': 250.0,
#   'year': 2016,
#   'month': 1,
#   'day': 28,
#   'eventDate': '2016-01-28T00:00:00',
#   'issues': ['COORDINATE_ROUNDED',
#    'GEODETIC_DATUM_ASSUMED_WGS84',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T22:33:57.454+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.11_1', 'name': 'Extremadura'},
#    'level2': {'gid': 'ESP.11.1_1', 'name': 'Badajoz'},
#    'level3': {'gid': 'ESP.11.1.6_1', 'name': 'n.a. (44)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'recordedBy': '-12753690',
#   'catalogNumber': '725046917',
#   'institutionCode': 'naturgucker',
#   'locality': 'Guadiana-Flusslandschaft in Merida',
#   'gbifID': '1338394937',
#   'collectionCode': 'naturgucker'},
#  {'key': 1413023877,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:31.163+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.64,
#   'decimalLatitude': 42.86,
#   'coordinateUncertaintyInMeters': 229.0,
#   'continent': 'EUROPE',
#   'stateProvince': 'Araba/Álava',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 21,
#   'eventDate': '2016-01-21T00:00:00',
#   'issues': ['INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:31.163+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.16_1', 'name': 'País Vasco'},
#    'level2': {'gid': 'ESP.16.1_1', 'name': 'Álava'},
#    'level3': {'gid': 'ESP.16.1.3_1', 'name': 'n.a. (3)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-287',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'municipality': 'Vitoria-Gasteiz',
#   'county': 'Arabako Lautada/Llanada Alavesa',
#   'locality': 'Duranzarra',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413023877',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-287',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': 'ACUAINV2016-287',
#   'recordedBy': 'María Arena',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413023879,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:31.163+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 2,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.72,
#   'decimalLatitude': 43.43,
#   'continent': 'EUROPE',
#   'waterBody': 'Desembocadura',
#   'year': 2016,
#   'month': 1,
#   'day': 20,
#   'eventDate': '2016-01-20T00:00:00',
#   'issues': ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:31.163+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:0010271',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'locality': 'Ría de Gernika',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413023879',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:0010271',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': '0010271',
#   'recordedBy': 'Jon Hidalgo',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'identifiedBy': 'S.O. Lanius',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024078,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:29.114+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.65,
#   'decimalLatitude': 42.86,
#   'coordinateUncertaintyInMeters': 669.0,
#   'continent': 'EUROPE',
#   'stateProvince': 'Araba/Álava',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 21,
#   'eventDate': '2016-01-21T00:00:00',
#   'issues': ['INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:29.114+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.16_1', 'name': 'País Vasco'},
#    'level2': {'gid': 'ESP.16.1_1', 'name': 'Álava'},
#    'level3': {'gid': 'ESP.16.1.3_1', 'name': 'n.a. (3)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-221',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'municipality': 'Vitoria-Gasteiz',
#   'county': 'Arabako Lautada/Llanada Alavesa',
#   'locality': 'Betoño',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024078',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-221',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': 'ACUAINV2016-221',
#   'recordedBy': 'María Arena',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024340,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:29.810+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.63,
#   'decimalLatitude': 42.86,
#   'coordinateUncertaintyInMeters': 618.0,
#   'continent': 'EUROPE',
#   'stateProvince': 'Araba/Álava',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 21,
#   'eventDate': '2016-01-21T00:00:00',
#   'issues': ['INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:29.810+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.16_1', 'name': 'País Vasco'},
#    'level2': {'gid': 'ESP.16.1_1', 'name': 'Álava'},
#    'level3': {'gid': 'ESP.16.1.3_1', 'name': 'n.a. (3)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-199',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'municipality': 'Vitoria-Gasteiz',
#   'county': 'Arabako Lautada/Llanada Alavesa',
#   'locality': 'Arkaute',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024340',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-199',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': 'ACUAINV2016-199',
#   'recordedBy': 'María Arena',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024475,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:30.033+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 1,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.65,
#   'decimalLatitude': 42.86,
#   'continent': 'EUROPE',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 21,
#   'eventDate': '2016-01-21T00:00:00',
#   'issues': ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:30.033+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.16_1', 'name': 'País Vasco'},
#    'level2': {'gid': 'ESP.16.1_1', 'name': 'Álava'},
#    'level3': {'gid': 'ESP.16.1.3_1', 'name': 'n.a. (3)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:0010142',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'locality': 'Betoño',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024475',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:0010142',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': '0010142',
#   'recordedBy': 'María Arena',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'identifiedBy': 'Ayuntamiento de Vitoria-Gasteiz',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024512,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:30.192+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.72,
#   'decimalLatitude': 43.43,
#   'coordinateUncertaintyInMeters': 12360.0,
#   'continent': 'EUROPE',
#   'waterBody': 'Desembocadura',
#   'year': 2016,
#   'month': 1,
#   'day': 20,
#   'eventDate': '2016-01-20T00:00:00',
#   'issues': ['INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:30.192+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-350',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'locality': 'Ría de Gernika',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024512',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-350',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': 'ACUAINV2016-350',
#   'recordedBy': 'Jon Hidalgo',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024558,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:30.121+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 1,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.9,
#   'decimalLatitude': 42.68,
#   'continent': 'EUROPE',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 17,
#   'eventDate': '2016-01-17T00:00:00',
#   'issues': ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:30.121+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.5_1', 'name': 'Castilla y León'},
#    'level2': {'gid': 'ESP.5.2_1', 'name': 'Burgos'},
#    'level3': {'gid': 'ESP.5.2.5_1', 'name': 'n.a. (63)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:0010217',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'locality': 'Lacorzana',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024558',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:0010217',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': '0010217',
#   'recordedBy': 'Izaskun Agirre',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'identifiedBy': 'Instituto Alavés de la Naturaleza',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024605,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:30.248+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 2,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.64,
#   'decimalLatitude': 42.86,
#   'continent': 'EUROPE',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 21,
#   'eventDate': '2016-01-21T00:00:00',
#   'issues': ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:30.248+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.16_1', 'name': 'País Vasco'},
#    'level2': {'gid': 'ESP.16.1_1', 'name': 'Álava'},
#    'level3': {'gid': 'ESP.16.1.3_1', 'name': 'n.a. (3)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:0010208',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'locality': 'Duranzarra',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024605',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:0010208',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': '0010208',
#   'recordedBy': 'María Arena',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'identifiedBy': 'Ayuntamiento de Vitoria-Gasteiz',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024650,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:30.276+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.9,
#   'decimalLatitude': 42.68,
#   'coordinateUncertaintyInMeters': 184.0,
#   'continent': 'EUROPE',
#   'stateProvince': 'Araba/Álava',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 17,
#   'eventDate': '2016-01-17T00:00:00',
#   'issues': ['INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:30.276+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.5_1', 'name': 'Castilla y León'},
#    'level2': {'gid': 'ESP.5.2_1', 'name': 'Burgos'},
#    'level3': {'gid': 'ESP.5.2.5_1', 'name': 'n.a. (63)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-296',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'municipality': 'Armiñón',
#   'county': 'Arabako Ibarrak/Valles Alaveses',
#   'locality': 'Lacorzana',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024650',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:ACUAINV2016-296',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': 'ACUAINV2016-296',
#   'recordedBy': 'Izaskun Agirre',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1413024716,
#   'datasetKey': '12dcaf31-c582-4c58-aefd-a8821ab7eb46',
#   'publishingOrgKey': '743cc32d-d83d-4e3a-a574-77d1725b1e08',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-13T17:16:55.267+00:00',
#   'lastParsed': '2020-12-15T20:29:30.362+00:00',
#   'crawlId': 128,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 105,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -2.63,
#   'decimalLatitude': 42.86,
#   'continent': 'EUROPE',
#   'waterBody': 'Humedal con dinámica natural',
#   'year': 2016,
#   'month': 1,
#   'day': 21,
#   'eventDate': '2016-01-21T00:00:00',
#   'issues': ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'lastInterpreted': '2020-12-15T20:29:30.362+00:00',
#   'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.16_1', 'name': 'País Vasco'},
#    'level2': {'gid': 'ESP.16.1_1', 'name': 'Álava'},
#    'level3': {'gid': 'ESP.16.1.3_1', 'name': 'n.a. (3)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'urn:EJGV:ocurrences:7:28:0010120',
#   'acceptedNameUsage': 'Ciconia ciconia Linnaeus, 1758',
#   'higherGeography': 'Europe | Spain | Basque Country',
#   'samplingEffort': 'Una jornada de censo en la época de invernada.',
#   'locality': 'Arkaute',
#   'datasetName': 'Censo de aves acuáticas invernantes',
#   'gbifID': '1413024716',
#   'language': 'es',
#   'collectionCode': 'ACUATICASINVERNANTESEU',
#   'occurrenceID': 'urn:EJGV:ocurrences:7:28:0010120',
#   'type': 'Event',
#   'taxonID': '10123',
#   'catalogNumber': '0010120',
#   'recordedBy': 'María Arena',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'EJGV',
#   'samplingProtocol': 'punto de conteo',
#   'occurrenceRemarks': 'Se ha tomado el centroide de la zona prospectada para aportar las coordenadas.',
#   'accessRights': '(cc) by http://creativecommons.org/licenses/by-sa/3.0/',
#   'identifiedBy': 'Ayuntamiento de Vitoria-Gasteiz',
#   'higherClassification': 'Animalia | Chordata | Aves | Ciconiiformes | Ciconiidae | Ciconia'},
#  {'key': 1576150121,
#   'datasetKey': '3ccbdf5b-7935-44f9-a7f9-fa3573b8b958',
#   'publishingOrgKey': '2d1fabab-9504-4cd8-aa19-79627dd3b010',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-11T06:22:13.190+00:00',
#   'lastParsed': '2020-12-15T21:05:59.073+00:00',
#   'crawlId': 116,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'establishmentMeans': 'NATIVE',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': 0.0,
#   'decimalLatitude': 0.0,
#   'continent': 'EUROPE',
#   'stateProvince': 'Cáceres',
#   'year': 2016,
#   'month': 1,
#   'day': 15,
#   'eventDate': '2016-01-15T00:00:00',
#   'issues': ['ZERO_COORDINATE',
#    'GEODETIC_DATUM_ASSUMED_WGS84',
#    'COUNTRY_COORDINATE_MISMATCH',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'modified': '2016-01-01T00:00:00.000+00:00',
#   'lastInterpreted': '2020-12-15T21:05:59.073+00:00',
#   'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'rightsHolder': 'SEO/BirdLife',
#   'identifier': 'SEO-BirdLife:acuaticas:038834022861340',
#   'habitat': 'Laguna',
#   'higherGeography': 'Cáceres',
#   'scientificNameID': '1340.00',
#   'samplingEffort': 'Censo con prismáticos/telescopio',
#   'locality': 'Charca San Cristóbal - Horco Espino (CC)',
#   'datasetName': 'SEO/BirdLife: Censos de aves acuáticas',
#   'gbifID': '1576150121',
#   'language': 'es',
#   'collectionCode': 'acuaticas',
#   'occurrenceID': 'SEO-BirdLife:acuaticas:038834022861340',
#   'type': 'Objeto físico',
#   'catalogNumber': '038834022861340',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'SEO-BirdLife',
#   'locationID': 'Charca San Cristóbal - Horco Espino (CC)',
#   'ownerInstitutionCode': 'SEO-BirdLife',
#   'samplingProtocol': 'Observación directa',
#   'bibliographicCitation': 'SEO/BirdLife, año. Censos de aves acuáticas compilados por SEO/BirdLife. Madrid.',
#   'accessRights': 'Sólo para uso no comercial',
#   'collectionID': 'www.acuaticas.org'},
#  {'key': 1576150212,
#   'datasetKey': '3ccbdf5b-7935-44f9-a7f9-fa3573b8b958',
#   'publishingOrgKey': '2d1fabab-9504-4cd8-aa19-79627dd3b010',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-11T06:22:13.190+00:00',
#   'lastParsed': '2020-12-15T21:05:56.637+00:00',
#   'crawlId': 116,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'establishmentMeans': 'NATIVE',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -3.828937,
#   'decimalLatitude': 40.728958,
#   'continent': 'EUROPE',
#   'stateProvince': 'Madrid',
#   'year': 2016,
#   'month': 1,
#   'day': 16,
#   'eventDate': '2016-01-16T00:00:00',
#   'issues': ['COORDINATE_ROUNDED',
#    'GEODETIC_DATUM_ASSUMED_WGS84',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'modified': '2016-01-01T00:00:00.000+00:00',
#   'lastInterpreted': '2020-12-15T21:05:56.637+00:00',
#   'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.8_1', 'name': 'Comunidad de Madrid'},
#    'level2': {'gid': 'ESP.8.1_1', 'name': 'Madrid'},
#    'level3': {'gid': 'ESP.8.1.5_1', 'name': 'n.a. (179)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'rightsHolder': 'SEO/BirdLife',
#   'identifier': 'SEO-BirdLife:acuaticas:038853009861340',
#   'habitat': 'Embalse',
#   'higherGeography': 'Madrid',
#   'scientificNameID': '1340.00',
#   'samplingEffort': 'Censo con prismáticos/telescopio',
#   'municipality': 'Manzanares El Real',
#   'locality': 'Embalse de Santillana (M)',
#   'datasetName': 'SEO/BirdLife: Censos de aves acuáticas',
#   'gbifID': '1576150212',
#   'language': 'es',
#   'collectionCode': 'acuaticas',
#   'occurrenceID': 'SEO-BirdLife:acuaticas:038853009861340',
#   'type': 'Objeto físico',
#   'higherGeographyID': 'Manzanares El Real',
#   'catalogNumber': '038853009861340',
#   'vernacularName': 'Cigüeña blanca',
#   'institutionCode': 'SEO-BirdLife',
#   'locationID': 'Embalse de Santillana (M)',
#   'ownerInstitutionCode': 'SEO-BirdLife',
#   'samplingProtocol': 'Observación directa',
#   'bibliographicCitation': 'SEO/BirdLife, año. Censos de aves acuáticas compilados por SEO/BirdLife. Madrid.',
#   'accessRights': 'Sólo para uso no comercial',
#   'collectionID': 'www.acuaticas.org'},
#  {'key': 1576150213,
#   'datasetKey': '3ccbdf5b-7935-44f9-a7f9-fa3573b8b958',
#   'publishingOrgKey': '2d1fabab-9504-4cd8-aa19-79627dd3b010',
#   'installationKey': '2a3f6a56-7591-4f05-8c4c-a1bb77aa4ea6',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-12-11T06:22:13.190+00:00',
#   'lastParsed': '2020-12-15T21:05:56.848+00:00',
#   'crawlId': 116,
#   'hostingOrganizationKey': '6c4a0bb0-2a4d-11d8-aa2d-b8a03c50a862',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'establishmentMeans': 'NATIVE',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -5.737044,
#   'decimalLatitude': 39.879031,
#   'continent': 'EUROPE',
#   'stateProvince': 'Cáceres',
#   'year': 2016,
#   'month': 1,
#   'day': 17,
#   'eventDate': '2016-01-17T00:00:00',
#   'issues': ['COORDINATE_ROUNDED',
#    'GEODETIC_DATUM_ASSUMED_WGS84',
#    'INSTITUTION_MATCH_NONE',
#    'COLLECTION_MATCH_NONE'],
#   'modified': '2016-01-01T00:00:00.000+00:00',
#   'lastInterpreted': '2020-12-15T21:05:56.848+00:00',
#   'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.11_1', 'name': 'Extremadura'},
#    'level2': {'gid': 'ESP.11.2_1', 'name': 'Cáceres'},
#    'level3': {'gid': 'ESP.11.2.9_1', 'name': 'n.a. (77)'}},
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
# ...
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -5.8254,
#   'decimalLatitude': 36.2416,
#   'stateProvince': 'Andalucía',
#   'year': 2016,
#   'month': 1,
#   'day': 31,
#   'eventDate': '2016-01-31T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T12:04:29.787+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.1_1', 'name': 'Andalucía'},
#    'level2': {'gid': 'ESP.1.2_1', 'name': 'Cádiz'},
#    'level3': {'gid': 'ESP.1.2.5_1', 'name': 'La Janda'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS370063320',
#   'recordedBy': 'obsr665436',
#   'catalogNumber': 'OBS370063320',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'La Janda--Canal Principal',
#   'county': 'Cádiz',
#   'gbifID': '1713122272',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS370063320'},
#  {'key': 1713269636,
#   'datasetKey': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'publishingOrgKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'installationKey': '7182d304-b0a2-404b-baba-2086a325c221',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-06-30T08:20:54.124+00:00',
#   'lastParsed': '2020-12-16T11:54:01.048+00:00',
#   'crawlId': 13,
#   'hostingOrganizationKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 15,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -6.19861,
#   'decimalLatitude': 39.4319,
#   'stateProvince': 'Extremadura',
#   'year': 2016,
#   'month': 1,
#   'day': 31,
#   'eventDate': '2016-01-31T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T11:54:01.048+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.11_1', 'name': 'Extremadura'},
#    'level2': {'gid': 'ESP.11.2_1', 'name': 'Cáceres'},
#    'level3': {'gid': 'ESP.11.2.6_1', 'name': 'n.a. (74)'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS370262493',
#   'recordedBy': 'obsr682644',
#   'catalogNumber': 'OBS370262493',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'Llanos de Cáceres--General (use specific hotspot if possible)',
#   'county': 'Cáceres',
#   'gbifID': '1713269636',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS370262493'},
#  {'key': 1713396167,
#   'datasetKey': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'publishingOrgKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'installationKey': '7182d304-b0a2-404b-baba-2086a325c221',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-06-30T08:20:54.124+00:00',
#   'lastParsed': '2020-12-16T11:54:09.984+00:00',
#   'crawlId': 13,
#   'hostingOrganizationKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -6.10815,
#   'decimalLatitude': 36.6067,
#   'stateProvince': 'Andalucía',
#   'year': 2016,
#   'month': 1,
#   'day': 23,
#   'eventDate': '2016-01-23T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T11:54:09.984+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.1_1', 'name': 'Andalucía'},
#    'level2': {'gid': 'ESP.1.2_1', 'name': 'Cádiz'},
#    'level3': {'gid': 'ESP.1.2.2_1', 'name': 'Campiña de Jerez'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS370481247',
#   'recordedBy': 'obsr676344',
#   'catalogNumber': 'OBS370481247',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'Roalabota',
#   'county': 'Cádiz',
#   'gbifID': '1713396167',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS370481247'},
#  {'key': 1713399231,
#   'datasetKey': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'publishingOrgKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'installationKey': '7182d304-b0a2-404b-baba-2086a325c221',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-06-30T08:20:54.124+00:00',
#   'lastParsed': '2020-12-16T11:54:06.157+00:00',
#   'crawlId': 13,
#   'hostingOrganizationKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -6.25778,
#   'decimalLatitude': 36.7706,
#   'stateProvince': 'Andalucía',
#   'year': 2016,
#   'month': 1,
#   'day': 23,
#   'eventDate': '2016-01-23T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T11:54:06.157+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.1_1', 'name': 'Andalucía'},
#    'level2': {'gid': 'ESP.1.2_1', 'name': 'Cádiz'},
#    'level3': {'gid': 'ESP.1.2.2_1', 'name': 'Campiña de Jerez'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS370482175',
#   'recordedBy': 'obsr676344',
#   'catalogNumber': 'OBS370482175',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'olivillo',
#   'county': 'Cádiz',
#   'gbifID': '1713399231',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS370482175'},
#  {'key': 1713401740,
#   'datasetKey': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'publishingOrgKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'installationKey': '7182d304-b0a2-404b-baba-2086a325c221',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-06-30T08:20:54.124+00:00',
#   'lastParsed': '2020-12-16T11:54:13.464+00:00',
#   'crawlId': 13,
#   'hostingOrganizationKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 1,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -4.05149,
#   'decimalLatitude': 40.4176,
#   'stateProvince': 'Madrid Comunidad de',
#   'year': 2016,
#   'month': 1,
#   'day': 31,
#   'eventDate': '2016-01-31T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T11:54:13.464+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.8_1', 'name': 'Comunidad de Madrid'},
#    'level2': {'gid': 'ESP.8.1_1', 'name': 'Madrid'},
#    'level3': {'gid': 'ESP.8.1.3_1', 'name': 'n.a. (177)'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS370483687',
#   'recordedBy': 'obsr688825',
#   'catalogNumber': 'OBS370483687',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'Quijorna',
#   'gbifID': '1713401740',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS370483687'},
#  {'key': 1713612821,
#   'datasetKey': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'publishingOrgKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'installationKey': '7182d304-b0a2-404b-baba-2086a325c221',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-06-30T08:20:54.124+00:00',
#   'lastParsed': '2020-12-16T12:04:03.676+00:00',
#   'crawlId': 13,
#   'hostingOrganizationKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 1,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': 0.297318,
#   'decimalLatitude': 41.8391,
#   'stateProvince': 'Aragón',
#   'year': 2016,
#   'month': 1,
#   'day': 27,
#   'eventDate': '2016-01-27T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T12:04:03.676+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.2_1', 'name': 'Aragón'},
#    'level2': {'gid': 'ESP.2.1_1', 'name': 'Huesca'},
#    'level3': {'gid': 'ESP.2.1.4_1', 'name': 'n.a. (128)'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS370986382',
#   'recordedBy': 'obsr428572',
#   'catalogNumber': 'OBS370986382',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'Binéfar--A22',
#   'county': 'Huesca',
#   'gbifID': '1713612821',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS370986382'},
#  {'key': 1713668637,
#   'datasetKey': '4fa7b334-ce0d-4e88-aaae-2e0c138d049e',
#   'publishingOrgKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'installationKey': '7182d304-b0a2-404b-baba-2086a325c221',
#   'publishingCountry': 'ES',
#   'protocol': 'DWC_ARCHIVE',
#   'lastCrawled': '2020-06-30T08:20:54.124+00:00',
#   'lastParsed': '2020-12-16T12:03:33.751+00:00',
#   'crawlId': 13,
#   'hostingOrganizationKey': 'e2e717bf-551a-4917-bdc9-4fa0f342c530',
#   'extensions': {},
#   'basisOfRecord': 'HUMAN_OBSERVATION',
#   'individualCount': 1,
#   'occurrenceStatus': 'PRESENT',
#   'taxonKey': 2481912,
#   'kingdomKey': 1,
#   'phylumKey': 44,
#   'classKey': 212,
#   'orderKey': 839,
#   'familyKey': 9289,
#   'genusKey': 2481908,
#   'speciesKey': 2481912,
#   'acceptedTaxonKey': 2481912,
#   'scientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'acceptedScientificName': 'Ciconia ciconia (Linnaeus, 1758)',
#   'kingdom': 'Animalia',
#   'phylum': 'Chordata',
#   'order': 'Ciconiiformes',
#   'family': 'Ciconiidae',
#   'genus': 'Ciconia',
#   'species': 'Ciconia ciconia',
#   'genericName': 'Ciconia',
#   'specificEpithet': 'ciconia',
#   'taxonRank': 'SPECIES',
#   'taxonomicStatus': 'ACCEPTED',
#   'decimalLongitude': -3.71843,
#   'decimalLatitude': 40.4237,
#   'stateProvince': 'Madrid Comunidad de',
#   'year': 2016,
#   'month': 1,
#   'day': 30,
#   'eventDate': '2016-01-30T00:00:00',
#   'issues': ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY'],
#   'lastInterpreted': '2020-12-16T12:03:33.751+00:00',
#   'license': 'http://creativecommons.org/publicdomain/zero/1.0/legalcode',
#   'identifiers': [],
#   'media': [],
#   'facts': [],
#   'relations': [],
#   'gadm': {'level0': {'gid': 'ESP', 'name': 'Spain'},
#    'level1': {'gid': 'ESP.8_1', 'name': 'Comunidad de Madrid'},
#    'level2': {'gid': 'ESP.8.1_1', 'name': 'Madrid'},
#    'level3': {'gid': 'ESP.8.1.3_1', 'name': 'n.a. (177)'}},
#   'institutionKey': '8d313059-3f5e-411e-b176-6553050ff8c6',
#   'isInCluster': False,
#   'geodeticDatum': 'WGS84',
#   'class': 'Aves',
#   'countryCode': 'ES',
#   'recordedByIDs': [],
#   'identifiedByIDs': [],
#   'country': 'Spain',
#   'identifier': 'OBS371208106',
#   'recordedBy': 'obsr270863',
#   'catalogNumber': 'OBS371208106',
#   'vernacularName': 'White Stork',
#   'institutionCode': 'CLO',
#   'locality': 'Jardines Templo de Debod, Madrid',
#   'gbifID': '1713668637',
#   'collectionCode': 'EBIRD',
#   'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS371208106'}]

# %%
df= pd.read_csv("../Data/species.csv")

# %%
dfs = {k: df[df['species'] == k] for k in df['species'].unique()}

# %%
len(dfs)
# Out:
# 11

# %%
dfs.keys()
# Out:
# dict_keys(['Apus affinis (J.E.Gray, 1830)', 'Apus caffer (Lichtenstein, 1823)', 'Parnassius apollo (Linnaeus, 1758)', 'Alytes dickhilleni Arntzen & García-París, 1995', 'Melitaea cinxia (Linnaeus, 1758)', 'Silene ciliata Pourr.', 'Abies pinsapo Boiss.', 'Lanius minor Gmelin, 1788', 'Ciconia ciconia (Linnaeus, 1758)', 'Sonchus tenerrimus L.', 'Araujia sericifera Brot.'])
